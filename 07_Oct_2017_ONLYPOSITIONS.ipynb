# %% [markdown]
# # Mutating hMOFs

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ## Create generation, constant mutation strength

# %%
import os

from ipywidgets import Text, HBox, Button, IntSlider, VBox, FloatSlider
from IPython.display import display, clear_output

import htsohm
from htsohm.files import load_config_file
from htsohm.hypothetical_MOFs.utilities import load_MOF, simulate, mutate_hMOF_sites

def create_children0(b):
    clear_output()
    print('CREATING GENERATION OF {} CHILDREN FROM {} AT MUTATION STRENGTH {}...\n'.format(child_select0.value, hMOF_select0.value, ms_select0.value))
    htsohm_path = os.path.dirname(os.path.dirname(htsohm.__file__))
    parent_path = os.path.join(htsohm_path, hMOF_select0.value)
    print(parent_path)
    config_path = os.path.join(parent_path, 'config.yaml')
    try:
        config = load_config_file(config_path)
        pm, ps = load_MOF(parent_path, config)
        print('\tRunning simulations ...')
        simulate(pm, ps, config)
        print('\t...done!')
        for i in range(child_select0.value):
            print('\nCHILD {} / {}\n'.format(i+1, child_select0.value))
            cm, cs = mutate_hMOF_sites(pm, ps, 1., config)
            print('\tRunning simulations ...')
            simulate(cm, cs, config)
            print('\t...done!')
        print('\n...GENERATION FINISHED!')
    except FileNotFoundError:
        print('Please select an hMOF with valid data path.')

child_select0 = IntSlider(description='No. of children : ', min=1, max=100, step=1, value=5)
hMOF_select0 = Text(placeholder='hMOF name (full)', description='Material : ')
ms_select0 = FloatSlider(description='Mutation strength : ', min=0., max=1., step=0.01, value=0.2)
load_button0 = Button(description='Load')
load_button0.on_click(create_children0)
HBox([VBox([hMOF_select0, child_select0]), VBox([load_button0])])
# Out:
# CREATING GENERATION OF 10 CHILDREN FROM hypotheticalMOF_3000136_i_1_j_23_k_23_m_12 AT MUTATION STRENGTH 0.2...
#
# /home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12
# .cif-file path : /home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12.cif
#
# NUMBER DENSITY, original : 0.011005548641587034
# NUMBER DENSITY NOT MODIFIED.
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_d6e1ac00-b4e1-4941-8034-b3faf1112c6b_a3602756-a264-4c8c-a3e6-33429b80e672
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:16:36.740301
# Calculating void fraction of d6e1ac00-b4e1-4941-8034-b3faf1112c6b...
#
# VOID FRACTION :   0.909005
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_d6e1ac00-b4e1-4941-8034-b3faf1112c6b_a36da15d-6d43-4b70-888f-d430c5371f71
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:16:38.675682
# Simulating methane loading in d6e1ac00-b4e1-4941-8034-b3faf1112c6b...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_d6e1ac00-b4e1-4941-8034-b3faf1112c6b_a36da15d-6d43-4b70-888f-d430c5371f71/Output/System_0/output_d6e1ac00-b4e1-4941-8034-b3faf1112c6b_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			13.1085699264	6.7923891651
# cc/g			293.8151684158	152.2444460142
# cc/cc			64.4342512161	33.3875100242
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-37325.65534		-212380.51642
# vdw		0.0		-37325.655336		-212380.516423
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_d6e1ac00-b4e1-4941-8034-b3faf1112c6b_36fc4bac-0a18-4124-8ab3-b559bbc22ca4
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:17:14.944407
# Calculating surface area of d6e1ac00-b4e1-4941-8034-b3faf1112c6b...
#
# SURFACE AREA
# 24724.199504	A^2
# 4892.634073	m^2/g
# 1072.96439	m^2/cm^3
# 	...done!
#
# CHILD 1 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_62c1a18a-77ec-4547-9a06-ee00eb155ca3_5a4801e7-b5fa-4933-8a52-23a85ace8cd7
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:17:38.410370
# Calculating void fraction of 62c1a18a-77ec-4547-9a06-ee00eb155ca3...
#
# VOID FRACTION :   0.585182
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_62c1a18a-77ec-4547-9a06-ee00eb155ca3_b817e74a-c848-4956-a75a-caaea1393310
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:17:40.280760
# Simulating methane loading in 62c1a18a-77ec-4547-9a06-ee00eb155ca3...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_62c1a18a-77ec-4547-9a06-ee00eb155ca3_b817e74a-c848-4956-a75a-caaea1393310/Output/System_0/output_62c1a18a-77ec-4547-9a06-ee00eb155ca3_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.6483964248	0.582285358
# cc/g			104.189044731	13.0513298929
# cc/cc			22.8488648777	2.8621826217
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4513.06608		-47688.42671
# vdw		0.0		-4513.066077		-47688.426708
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_62c1a18a-77ec-4547-9a06-ee00eb155ca3_0b480817-c602-4ef4-bf17-d1f9854c2125
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:17:52.654445
# Calculating surface area of 62c1a18a-77ec-4547-9a06-ee00eb155ca3...
#
# SURFACE AREA
# 74532.438564	A^2
# 14749.110418	m^2/g
# 3234.50927	m^2/cm^3
# 	...done!
#
# CHILD 2 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2c549aab-ddb2-484f-96fc-98ee05937762_7f93379c-e6b7-4425-8ce7-8663a354d6b6
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:18:26.362069
# Calculating void fraction of 2c549aab-ddb2-484f-96fc-98ee05937762...
#
# VOID FRACTION :   0.581068
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2c549aab-ddb2-484f-96fc-98ee05937762_a52a33ea-bb09-4765-8c6d-0fa21147df41
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:18:28.231502
# Simulating methane loading in 2c549aab-ddb2-484f-96fc-98ee05937762...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2c549aab-ddb2-484f-96fc-98ee05937762_a52a33ea-bb09-4765-8c6d-0fa21147df41/Output/System_0/output_2c549aab-ddb2-484f-96fc-98ee05937762_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.7036014721	0.6660763511
# cc/g			105.4264093228	14.9294191803
# cc/cc			23.1202213954	3.2740513404
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4372.23243		-48459.37279
# vdw		0.0		-4372.232427		-48459.372787
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2c549aab-ddb2-484f-96fc-98ee05937762_0495353c-c461-440f-8474-f1711082a311
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:18:40.128588
# Calculating surface area of 2c549aab-ddb2-484f-96fc-98ee05937762...
#
# SURFACE AREA
# 72208.144344	A^2
# 14289.159385	m^2/g
# 3133.641093	m^2/cm^3
# 	...done!
#
# CHILD 3 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2e45c725-e496-42d7-ba11-8c4ec174fbbc_5dc01c07-9021-40c5-ba37-4ca1191bae41
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:19:13.539754
# Calculating void fraction of 2e45c725-e496-42d7-ba11-8c4ec174fbbc...
#
# VOID FRACTION :   0.584936
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2e45c725-e496-42d7-ba11-8c4ec174fbbc_e6e3cbdd-e259-4894-b2c8-ebc75b4f1e37
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:19:15.412454
# Simulating methane loading in 2e45c725-e496-42d7-ba11-8c4ec174fbbc...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2e45c725-e496-42d7-ba11-8c4ec174fbbc_e6e3cbdd-e259-4894-b2c8-ebc75b4f1e37/Output/System_0/output_2e45c725-e496-42d7-ba11-8c4ec174fbbc_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.8619873817	0.797585635
# cc/g			108.9764672586	17.8770650785
# cc/cc			23.8987561665	3.9204759526
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4956.95943		-49797.18338
# vdw		0.0		-4956.959432		-49797.183384
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_2e45c725-e496-42d7-ba11-8c4ec174fbbc_7c8406ea-071a-47df-abba-2ef57ffdfeed
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:19:26.779418
# Calculating surface area of 2e45c725-e496-42d7-ba11-8c4ec174fbbc...
#
# SURFACE AREA
# 73862.000016	A^2
# 14616.438358	m^2/g
# 3205.414023	m^2/cm^3
# 	...done!
#
# CHILD 4 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_a17f88db-9cfa-4cff-a738-a362e0cef864_33f9d6cb-1e4b-4c43-8637-3348dbf8f9a5
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:20:00.727110
# Calculating void fraction of a17f88db-9cfa-4cff-a738-a362e0cef864...
#
# VOID FRACTION :   0.591367
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_a17f88db-9cfa-4cff-a738-a362e0cef864_6786ef92-9b24-44d1-9c7c-a25704a55691
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:20:02.585573
# Simulating methane loading in a17f88db-9cfa-4cff-a738-a362e0cef864...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_a17f88db-9cfa-4cff-a738-a362e0cef864_6786ef92-9b24-44d1-9c7c-a25704a55691/Output/System_0/output_a17f88db-9cfa-4cff-a738-a362e0cef864_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.7718881857	0.6497974811
# cc/g			106.9569860635	14.564544982
# cc/cc			23.3818866089	3.1839578864
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4741.08376		-48740.40754
# vdw		0.0		-4741.083763		-48740.407541
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_a17f88db-9cfa-4cff-a738-a362e0cef864_901342c1-c357-4455-8bda-323ab56d8e81
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:20:14.403197
# Calculating surface area of a17f88db-9cfa-4cff-a738-a362e0cef864...
#
# SURFACE AREA
# 74528.803905	A^2
# 14795.063285	m^2/g
# 3234.351535	m^2/cm^3
# 	...done!
#
# CHILD 5 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_f5990988-2283-44bb-899b-68629a5e8485_b3c55c95-ba64-42f7-a3c7-126c10a34b94
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:20:48.315661
# Calculating void fraction of f5990988-2283-44bb-899b-68629a5e8485...
#
# VOID FRACTION :   0.594139
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_f5990988-2283-44bb-899b-68629a5e8485_6c973f32-2a43-4022-86d1-219328f5c871
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:20:50.181805
# Simulating methane loading in f5990988-2283-44bb-899b-68629a5e8485...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_f5990988-2283-44bb-899b-68629a5e8485_6c973f32-2a43-4022-86d1-219328f5c871/Output/System_0/output_f5990988-2283-44bb-899b-68629a5e8485_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.7916666667	0.6633182843
# cc/g			107.4003004572	14.8675999363
# cc/cc			23.5530996499	3.2604942571
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4695.26165		-51761.8664
# vdw		0.0		-4695.261648		-51761.866403
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_f5990988-2283-44bb-899b-68629a5e8485_c3baaa56-1333-490c-b909-5f7781dc791f
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:21:02.234326
# Calculating surface area of f5990988-2283-44bb-899b-68629a5e8485...
#
# SURFACE AREA
# 75891.725707	A^2
# 15018.097674	m^2/g
# 3293.498711	m^2/cm^3
# 	...done!
#
# CHILD 6 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_75031102-2014-46df-89b1-a38ba12c4796_f00432e9-ca90-4077-88c9-191b22c96392
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:21:36.234818
# Calculating void fraction of 75031102-2014-46df-89b1-a38ba12c4796...
#
# VOID FRACTION :   0.578836
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_75031102-2014-46df-89b1-a38ba12c4796_93eb02a7-d89e-46b5-a12e-388631efe8db
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:21:38.133980
# Simulating methane loading in 75031102-2014-46df-89b1-a38ba12c4796...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_75031102-2014-46df-89b1-a38ba12c4796_93eb02a7-d89e-46b5-a12e-388631efe8db/Output/System_0/output_75031102-2014-46df-89b1-a38ba12c4796_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.7009726604	0.678956492
# cc/g			105.3674871994	15.2181143443
# cc/cc			23.1072996565	3.3373627644
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4614.36084		-48214.87267
# vdw		0.0		-4614.360837		-48214.872671
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_75031102-2014-46df-89b1-a38ba12c4796_b07de5ae-f431-4abf-83d6-a0dc90f5f45b
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:21:49.922866
# Calculating surface area of 75031102-2014-46df-89b1-a38ba12c4796...
#
# SURFACE AREA
# 73282.73694	A^2
# 14501.808873	m^2/g
# 3180.275549	m^2/cm^3
# 	...done!
#
# CHILD 7 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_c3a47952-b0fe-4a87-b5cd-a069262eb469_6493f405-fb24-4bd4-acac-1ecd62e64de3
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:22:23.575140
# Calculating void fraction of c3a47952-b0fe-4a87-b5cd-a069262eb469...
#
# VOID FRACTION :   0.593607
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_c3a47952-b0fe-4a87-b5cd-a069262eb469_641efffd-1d7b-4bbe-ab17-557c0bf2bd01
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:22:25.495502
# Simulating methane loading in c3a47952-b0fe-4a87-b5cd-a069262eb469...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_c3a47952-b0fe-4a87-b5cd-a069262eb469_641efffd-1d7b-4bbe-ab17-557c0bf2bd01/Output/System_0/output_c3a47952-b0fe-4a87-b5cd-a069262eb469_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.952681388	0.8280295839
# cc/g			111.0092805165	18.5594350121
# cc/cc			24.3445561599	4.0701210371
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-5112.67471		-49300.22593
# vdw		0.0		-5112.67471		-49300.225933
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_c3a47952-b0fe-4a87-b5cd-a069262eb469_8c650b15-f313-4d53-9a50-130e86f3167b
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:22:37.651649
# Calculating surface area of c3a47952-b0fe-4a87-b5cd-a069262eb469...
#
# SURFACE AREA
# 72894.136497	A^2
# 14424.909325	m^2/g
# 3163.411325	m^2/cm^3
# 	...done!
#
# CHILD 8 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_959d5cdf-e2bd-4744-a43e-9599baa64bd0_d10058bc-1514-40d8-bfc6-3935710ad9df
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:23:11.151349
# Calculating void fraction of 959d5cdf-e2bd-4744-a43e-9599baa64bd0...
#
# VOID FRACTION :   0.597416
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_959d5cdf-e2bd-4744-a43e-9599baa64bd0_0d2c2998-3d48-4a2b-9b69-43b21db1a06c
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:23:13.019450
# Simulating methane loading in 959d5cdf-e2bd-4744-a43e-9599baa64bd0...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_959d5cdf-e2bd-4744-a43e-9599baa64bd0_0d2c2998-3d48-4a2b-9b69-43b21db1a06c/Output/System_0/output_959d5cdf-e2bd-4744-a43e-9599baa64bd0_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			5.0157728707	0.8646543997
# cc/g			112.4234114785	19.3803427447
# cc/cc			24.6546778944	4.2501477368
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-5233.76153		-50293.30693
# vdw		0.0		-5233.761528		-50293.306931
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_959d5cdf-e2bd-4744-a43e-9599baa64bd0_e5004fd3-3efe-4a88-827c-f15cdef05c7e
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:23:25.515461
# Calculating surface area of 959d5cdf-e2bd-4744-a43e-9599baa64bd0...
#
# SURFACE AREA
# 72549.26988	A^2
# 14356.664196	m^2/g
# 3148.445032	m^2/cm^3
# 	...done!
#
# CHILD 9 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_91a71980-aaa4-44eb-8239-22bd14baa1cf_315fc691-e6f1-46fa-9dbf-25222b4a7141
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:23:59.830178
# Calculating void fraction of 91a71980-aaa4-44eb-8239-22bd14baa1cf...
# VOID FRACTION :   0.5958
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_91a71980-aaa4-44eb-8239-22bd14baa1cf_fb8709b2-3a41-4b3f-8288-a61f446066aa
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:24:02.649890
# Simulating methane loading in 91a71980-aaa4-44eb-8239-22bd14baa1cf...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_91a71980-aaa4-44eb-8239-22bd14baa1cf_fb8709b2-3a41-4b3f-8288-a61f446066aa/Output/System_0/output_91a71980-aaa4-44eb-8239-22bd14baa1cf_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.5820189274	0.4421291605
# cc/g			102.7012611148	9.9098722809
# cc/cc			22.5225909695	2.1732547149
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-4216.80745		-46688.81302
# vdw		0.0		-4216.807453		-46688.813019
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_91a71980-aaa4-44eb-8239-22bd14baa1cf_cdb8add9-d3c0-4a55-8962-78466f2048e9
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:24:15.631076
# Calculating surface area of 91a71980-aaa4-44eb-8239-22bd14baa1cf...
#
# SURFACE AREA
# 72400.652561	A^2
# 14327.254542	m^2/g
# 3141.995437	m^2/cm^3
# 	...done!
#
# CHILD 10 / 10
#
# 	Running simulations ...
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_676e08fa-5f53-44f4-9387-bd7690eebaaa_04f038e0-30e7-44ec-83b2-75d3b0833dff
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:24:50.986596
# Calculating void fraction of 676e08fa-5f53-44f4-9387-bd7690eebaaa...
#
# VOID FRACTION :   0.592814
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_676e08fa-5f53-44f4-9387-bd7690eebaaa_6ac4b282-9362-4fd2-906f-345007f37ebb
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:24:53.278621
# Simulating methane loading in 676e08fa-5f53-44f4-9387-bd7690eebaaa...
# OUTPUT FILE:	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_676e08fa-5f53-44f4-9387-bd7690eebaaa_6ac4b282-9362-4fd2-906f-345007f37ebb/Output/System_0/output_676e08fa-5f53-44f4-9387-bd7690eebaaa_2.2.2_298.000000_3.5e+06.data
#
# methane ADSORPTION	absolute	excess
# mol/kg			4.7298895899	0.610747911
# cc/g			106.0156305569	13.6892888649
# cc/cc			23.2494387848	3.002088294
#
# ENERGIES	host-host	adsorbate-adsorbate	host-adsorbate
# avg		0.0		-5143.09584		-49166.65254
# vdw		0.0		-5143.095844		-49166.652542
# cou		0.0		0.0			0.0
#
# Output directory :	/home/akaija/repos/HTSOHM-dev/hypotheticalMOF_3000136_i_1_j_23_k_23_m_12/output_676e08fa-5f53-44f4-9387-bd7690eebaaa_26edb974-1148-4c1b-bd75-11fcb274e3c3
# {'gamma': 59.994604000000002, 'beta': 60.009005999999999, 'alpha': 60.004510000000003}
# Date :	2017-10-22
# Time :	01:25:09.146095
# Calculating surface area of 676e08fa-5f53-44f4-9387-bd7690eebaaa...
#
# SURFACE AREA
# 73731.050913	A^2
# 14590.52504	m^2/g
# 3199.731181	m^2/cm^3
# 	...done!
#
# ...GENERATION FINISHED!

# %% [markdown]
# ### Plot results

# %%
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib as mpl

from ipywidgets import Dropdown
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sqlalchemy import create_engine, or_
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

from htsohm.hypothetical_MOFs.utilities import make_query, plot_parent
from non_pseudo.db import Material as np_m

matplotlib.rcParams.update({'font.size': 22})

def plot0(b):
    clear_output()
    htsohm_path = os.path.dirname(os.path.dirname(htsohm.__file__))
    parent_path = os.path.join(htsohm_path, hMOF_select0.value)
    config_path = os.path.join(parent_path, 'config.yaml')
    try:
        config = load_config_file(config_path)
        
        np_cs = "postgresql://htsohm:dentate-canst-freely@127.0.01/non_pseudo3"
        np_engine = create_engine(np_cs)
        np_s = sessionmaker(bind=np_engine)()
        
        if x_select0.value == 'ga0_absolute_volumetric_loading':
            x_o_s = 'ga1_absolute_volumetric_loading'
        else:
            x_o_s = x_select0.value
        if y_select0.value == 'ga0_absolute_volumetric_loading':
            y_o_s = 'ga1_absolute_volumetric_loading'
        else:
            y_o_s = y_select0.value
        
        x_o = np_s.query(getattr(np_m, x_o_s)).filter(np_m.name==hMOF_select0.value).one()[0]
        y_o = np_s.query(getattr(np_m, y_o_s)).filter(np_m.name==hMOF_select0.value).one()[0]
        
        x0 = make_query(x_select0.value, hMOF_select0.value, 0)
        x1 = make_query(x_select0.value, hMOF_select0.value, 1)
        y0 = make_query(y_select0.value, hMOF_select0.value, 0)
        y1 = make_query(y_select0.value, hMOF_select0.value, 1)       
        c0 = make_query(c_select0.value, hMOF_select0.value, 0)       
        c1 = make_query(c_select0.value, hMOF_select0.value, 1)
        if isinstance(c0, list):
            c = [*c0, *c1]
            x = [*x0, *x1]
            y = [*y0, *y1]
        else:
            c = [c0, *c1]
            x = [x0, *x1]
            y = [y0, *y1]
        [min_c, max_c] = [min(c), max(c)]
#        c = [(e - min(c)) / float(max(c) - min(c)) for e in c]
        #c0 = [(e - min(c)) / (max(c) - min(c)) for e in c0]
        #c1 = [(e - min(c)) / (max(c) - min(c)) for e in c1]
        fig, ax = plot_parent(x_select0.value, y_select0.value, hMOF_select0.value, config)
        ax.patch.set_alpha(0.0)
        plt.scatter(x0, y0, facecolor='r', edgecolor='none', marker='^', s=40)
        plt.scatter(x1, y1, facecolor='r', edgecolor='none')
        im = plt.scatter(x1, y1, c=c1, cmap=cm.jet_r, edgecolor='none')
        plt.scatter(x_o, y_o, facecolor='none', edgecolor='r', s=80)
        
        cbar = fig.colorbar(im, ax=ax)
        im.set_clim(min(min_c, max_c))
        cbar.set_label(c_select0.value)
        
        plt.show()
        
#        plot_parent_and_children(hMOF_select0.value, config)
    except FileNotFoundError:
        print('Please select an hMOF with valid data path.')

x_y = ['vf_helium_void_fraction',
       'ga0_absolute_volumetric_loading',
       'sa_volumetric_surface_area']
c = [*x_y, 'average_sigma', 'average_epsilon', 'number_density', 'unit_cell_volume']
        
x_select0 = Dropdown(options=[*x_y], description='X-axis : ')
y_select0 = Dropdown(options=[*x_y], description='Y-axis : ')
c_select0 = Dropdown(options=[*c], description='Color by : ')
plot_button0 = Button(description='Plot results!')
plot_button0.on_click(plot0)

HBox([VBox([x_select0, y_select0]), VBox([c_select0, plot_button0])])

# %% [markdown]
# ### Clear data

# %%
from htsohm.db import session, Material

def delete0(b):
    ids = [e[0] for e in session.query(Material.id).filter(Material.run_id==hMOF_select0.value).all()]
    for some_id in ids:
        row = session.query(Material).get(some_id)
        session.delete(row)
        session.commit()
    
del_button0 = Button(description='Delete data')
del_button0.on_click(delete0)

del_button0
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
